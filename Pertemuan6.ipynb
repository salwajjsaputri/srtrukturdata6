# %% [markdown]
# SORTING

# %% [markdown]
# 1. Implementasi Bubble Sort

# %%
def bubble_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        for j in range(n - i - 1):
            if arr[j] > arr[j + 1]:
                arr[j], arr[j + 1] = arr[j + 1], arr[j]
    return arr

# Contoh penggunaan
data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = bubble_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Bubble Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Bubble Sort: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# 2. Implementasi Selection Sort

# %%
def selection_sort(arr):
    n = len(arr)
    for i in range(n - 1):
        min_index = i
        for j in range(i + 1, n):
            if arr[j] < arr[min_index]:
                min_index = j
        arr[i], arr[min_index] = arr[min_index], arr[i]
    return arr

data = [64, 25, 12, 22, 11]
sorted_data = selection_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Selection Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Selection Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# 3. Implementasi Insertion Sort

# %%
def insertion_sort(arr):
    n = len(arr)
    for i in range(1, n):
        key = arr[i]
        j = i - 1
        while j >= 0 and arr[j] > key:
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key
    return arr

data = [64, 34, 25, 12, 22, 11, 90]
sorted_data = insertion_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Insertion Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 34, 25, 12, 22, 11, 90]
# Data setelah Insertion Sort: [11, 12, 22, 25, 34, 64, 90]

# %% [markdown]
# 4. Implementasi Merge Sort

# %%
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left_half = arr[:mid]
        right_half = arr[mid:]

        merge_sort(left_half)
        merge_sort(right_half)

        i = j = k = 0

        while i < len(left_half) and j < len(right_half):
            if left_half[i] < right_half[j]:
                arr[k] = left_half[i]
                i += 1
            else:
                arr[k] = right_half[j]
                j += 1
            k += 1

        while i < len(left_half):
            arr[k] = left_half[i]
            i += 1
            k += 1

        while j < len(right_half):
            arr[k] = right_half[j]
            j += 1
            k += 1
    return arr

data = [64, 25, 12, 22, 11]
sorted_data = merge_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Merge Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Merge Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# 5. Implementasi Quick Sort

# %%
def quick_sort(arr):
    if len(arr) <= 1:
        return arr
    pivot = arr[len(arr) // 2]
    left = [x for x in arr if x < pivot]
    middle = [x for x in arr if x == pivot]
    right = [x for x in arr if x > pivot]
    return quick_sort(left) + middle + quick_sort(right)

data = [64, 25, 12, 22, 11]
sorted_data = quick_sort(data.copy())
print("Data sebelum sorting:", data)
print("Data setelah Quick Sort:", sorted_data)
# Out:
# Data sebelum sorting: [64, 25, 12, 22, 11]
# Data setelah Quick Sort: [11, 12, 22, 25, 64]

# %% [markdown]
# LATIHAN/TUGAS : Pengurutan Hasil Ujian Mahasiswa (Rombel 03)

# %%
# TUGAS 3 - PENGURUTAN HASIL UJIAN MAHASISWA
# Mengurutkan nilai dari tertinggi ke terendah pakai Quick Sort

def quick_sort_mahasiswa(data, key='nilai', descending=True):
    if len(data) <= 1:
        return data

    tengah = len(data) // 2
    pivot = data[tengah]

    kiri = []
    tengah_list = []
    kanan = []

    for x in data:
        if descending:
            if x[key] > pivot[key]:
                kiri.append(x)
            elif x[key] == pivot[key]:
                tengah_list.append(x)
            else:
                kanan.append(x)
        else:
            if x[key] < pivot[key]:
                kiri.append(x)
            elif x[key] == pivot[key]:
                tengah_list.append(x)
            else:
                kanan.append(x)

    return quick_sort_mahasiswa(kiri, key, descending) + tengah_list + quick_sort_mahasiswa(kanan, key, descending)

# Data mahasiswa
mahasiswa = [
    {"nama": "Asep", "nilai": 81},
    {"nama": "Binar", "nilai": 100},
    {"nama": "Randhika", "nilai": 92},
    {"nama": "Jagas", "nilai": 97},
    {"nama": "Rindu", "nilai": 86},
    {"nama": "UcupKurucup", "nilai": 70}
]

# Tampilkan sebelum sorting
print("=== DATA SEBELUM SORTING ===")
for m in mahasiswa:
    print(m['nama'], ":", m['nilai'])

# Proses sorting
hasil = quick_sort_mahasiswa(mahasiswa.copy())

# Tampilkan setelah sorting
print("\n=== DATA SETELAH SORTING (NILAI TERTINGGI KE TERENDAH) ===")
for i in range(len(hasil)):
    print("Peringkat", i+1, ":", hasil[i]['nama'], "- Nilai", hasil[i]['nilai'])
# Out:
# === DATA SEBELUM SORTING ===
# Asep : 81
# Binar : 100
# Randhika : 92
# Jagas : 97
# Rindu : 86
# UcupKurucup : 70
#
# === DATA SETELAH SORTING (NILAI TERTINGGI KE TERENDAH) ===
# Peringkat 1 : Binar - Nilai 100
# Peringkat 2 : Jagas - Nilai 97
# Peringkat 3 : Randhika - Nilai 92
# Peringkat 4 : Rindu - Nilai 86
# Peringkat 5 : Asep - Nilai 81
# Peringkat 6 : UcupKurucup - Nilai 70
